# %% [markdown]
# ---
# subtitle: "Cargando tablas en LaTex"
# lang: es
# date: "2024-09-17"
# format:
#     pdf:
#       documentclass: report
#       papersize: a4
#       classoption: [onecolumn, portrait]
#       lof: false
#       lot: false
#       geometry:
#         - top=3mm
#         - left=3mm
#         - right=3mm
#         - bottom=3mm
# execute:
#   echo: false
#   warning: false
# ---

# %% [markdown]
# # Primeros pasos con positron
# ## Carga de tablas

# %%
#| tbl-cap: "Parámetros"
import pandas as pd
a = pd.read_excel("ESPG-UNJBG.xlsx", index_col=0).iloc[1:30,0:11]
a.agg(func = round)
# Out:
#                      pm25  pm10  pres   pp  temp    hr   wd   ws  rad    no   no2
# date
# 2024-08-23 01:00:00  12.0  17.0   948  0.0  11.0  95.0  190  1.0  0.0   2.0  13.0
# 2024-08-23 02:00:00  12.0  16.0   947  0.0  10.0  95.0   23  1.0  0.0   1.0  12.0
# 2024-08-23 03:00:00   9.0  11.0   946  0.0  10.0  95.0  309  1.0  0.0   1.0  11.0
# 2024-08-23 04:00:00  11.0  14.0   946  0.0  10.0  94.0  337  1.0  0.0   1.0  13.0
# 2024-08-23 05:00:00   9.0  12.0   946  0.0  10.0  95.0   56  1.0  0.0   1.0  13.0
# 2024-08-23 06:00:00   9.0  13.0   946  0.0  10.0  94.0   22  1.0  0.0   3.0  14.0
# 2024-08-23 07:00:00  10.0  12.0   947  0.0  10.0  94.0  196  1.0  0.0   4.0  15.0
# 2024-08-23 08:00:00  12.0  14.0   948  0.0  10.0  90.0  260  1.0  0.0  17.0  19.0
# 2024-08-23 09:00:00  14.0  20.0   948  0.0  11.0  85.0  154  1.0  0.0  15.0  18.0
# 2024-08-23 10:00:00  17.0  31.0   949  0.0  12.0  84.0  247  1.0  0.0  24.0  23.0
# ...
